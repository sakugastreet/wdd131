# %%
from polygon import RESTClient

client = RESTClient("dvvnexV3mAsnl31MnP5zCGphd55Yrwaa")

tickers = ["AAPL"]
for t in client.list_tickers(
	market="stocks",
	active="true",
	order="asc",
	limit="100",
	sort="ticker",
	):
    tickers.append(t)

print(tickers)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[2], line 6
#       3 client = RESTClient("dvvnexV3mAsnl31MnP5zCGphd55Yrwaa")
#       5 tickers = ["AAPL"]
# ----> 6 for t in client.list_tickers(
#       7 	market="stocks",
#       8 	active="true",
#       9 	order="asc",
#      10 	limit="100",
#      11 	sort="ticker",
#      12 	):
#      13     tickers.append(t)
#      15 print(tickers)
#
# File c:\Users\josep\AppData\Local\Programs\Python\Python312\Lib\site-packages\polygon\rest\base.py:211, in BaseClient._paginate_iter(self, path, params, deserializer, result_key, options)
#     202 def _paginate_iter(
#     203     self,
#     204     path: str,
#    (...)
# ...

# %%
from polygon import RESTClient

client = RESTClient("dvvnexV3mAsnl31MnP5zCGphd55Yrwaa")

# List options for AAPL
options = client.list_options_contracts(underlying_ticker="AAPL", limit=10)

for option in options:
    print(option)
# Out:
# OptionsContract(additional_underlyings=None, cfi='OCASPS', contract_type='call', correction=None, exercise_style='american', expiration_date='2025-05-02', primary_exchange='BATO', shares_per_contract=100, strike_price=100, ticker='O:AAPL250502C00100000', underlying_ticker='AAPL')
# OptionsContract(additional_underlyings=None, cfi='OCASPS', contract_type='call', correction=None, exercise_style='american', expiration_date='2025-05-02', primary_exchange='BATO', shares_per_contract=100, strike_price=110, ticker='O:AAPL250502C00110000', underlying_ticker='AAPL')
# OptionsContract(additional_underlyings=None, cfi='OCASPS', contract_type='call', correction=None, exercise_style='american', expiration_date='2025-05-02', primary_exchange='BATO', shares_per_contract=100, strike_price=120, ticker='O:AAPL250502C00120000', underlying_ticker='AAPL')
# ...
